# %%
import random
import glob as g
import skimage as sk
from skimage import io
from skimage import util
from scipy import ndarray
from skimage import transform

# %%
def random_rotation(image_array: ndarray):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-90, 90)
    return sk.transform.rotate(image_array, random_degree)

#def random_noise(image_array: ndarray):
#    # add random noise to the image
#    return sk.util.random_noise(image_array)
def vertical_flip(image_array: ndarray):
    return image_array[::-1, :]

def horizontal_flip(image_array: ndarray):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

# dictionary of the transformations we defined earlier
available_transformations = {
    'rotate': random_rotation,
    #'noise': random_noise,
    'vertical_flip':vertical_flip,
    'horizontal_flip': horizontal_flip
}

# %%
folder_path='C:\\Users\\SEO\\Desktop\\Makenaide\\data\\img_dataset\\data_full'
folder_list=g.glob(folder_path+'\\*')

num_files_desired = [1388, 2041, 1300, 1300, 1272, 1168, 1583, 5630, 1352]

# find all files paths from the folder
for th, num_files in zip(range(9), num_files_desired):

    images = g.glob(folder_list[th]+'\\NG\\*')

    num_generated_files = 1
    while num_generated_files <= num_files :

        # random image from the folder
        image_path = random.choice(images)

        # read image as an two dimensional array of pixels
        image_to_transform = sk.io.imread(image_path)

        # random num of transformation to apply
        num_transformations_to_apply = random.randint(1, len(available_transformations))

        num_transformations = 0
        transformed_image = None

        while num_transformations <= num_transformations_to_apply:

            # random transformation to apply for a single image
            key = random.choice(list(available_transformations))
            transformed_image = available_transformations[key](image_to_transform)
            num_transformations += 1

        new_file_path = folder_list[th]+'\\AugNG\\%s_augimg.bmp' % (num_generated_files)

        # write image to the disk
        io.imsave(new_file_path, transformed_image)
        num_generated_files += 1
# Out:
# c:\users\seo\desktop\seo_project\lib\site-packages\skimage\util\dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# c:\users\seo\desktop\seo_project\lib\site-packages\skimage\io\_io.py:140: UserWarning: C:\Users\SEO\Desktop\Makenaide\data\img_dataset\data_full\dent\AugNG\20_augimg.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# c:\users\seo\desktop\seo_project\lib\site-packages\skimage\io\_io.py:140: UserWarning: C:\Users\SEO\Desktop\Makenaide\data\img_dataset\data_full\dent\AugNG\58_augimg.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# c:\users\seo\desktop\seo_project\lib\site-packages\skimage\io\_io.py:140: UserWarning: C:\Users\SEO\Desktop\Makenaide\data\img_dataset\data_full\dent\AugNG\76_augimg.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ...
